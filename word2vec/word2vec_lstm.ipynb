# %% [markdown]
# # Urgency Dataset

# %%
# read the csv data in the google sheets and gather all of the sentences  
import pandas as pd


dataset = pd.read_csv("../UrgencySentenceSamples.csv", encoding="utf-8") 
ohe = pd.get_dummies(dataset["Label"])
dataset = pd.concat([dataset["Sentence"], ohe], axis=1)
dataset.head(5)
# Out:
#                                             Sentence  critical  info  warning
# 0     As of today 60 people went missing on the park         1     0        0
# 1  The biker was injured on the street and now is...         1     0        0
# 2    The president has been kidnapped by terrorists          1     0        0
# 3  People in Louisiana are in dire need of food a...         1     0        0
# 4  Five cars were hit and are now stranded beneat...         1     0        0

# %%
# pre-process text 
import nltk
nltk.download('omw-1.4')
import re 
from nltk.corpus import stopwords
import string
nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 

lines = dataset['Sentence'].values.tolist()

def text_normalization(lines):
    cleaned_data = []
    for line in lines: 
      line = line.lower()
      line = re.sub(r'[^\w\s]', '', line)
      words = word_tokenize(line) 
      cleaned_line = [word for word in words if not word in set(stopwords.words('english'))] 
      cleaned_line = [WordNetLemmatizer().lemmatize(word) for word in cleaned_line] 
      #cleaned_line_text = ' '.join([str(word) for word in cleaned_line])
      cleaned_data.append(cleaned_line)
    
    return cleaned_data
  
cleaned_data = text_normalization(lines)
print(cleaned_data)
# Out:
# [nltk_data] Downloading package omw-1.4 to /Users/aszeto1/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aszeto1/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/aszeto1/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/aszeto1/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [['today', '60', 'people', 'went', 'missing', 'park'], ['biker', 'injured', 'street', 'critical', 'need', 'medical', 'attention'], ['president', 'kidnapped', 'terrorist'], ['people', 'louisiana', 'dire', 'need', 'food', 'hurricane', 'destroyed', 'home'], ['five', 'car', 'hit', 'stranded', 'beneath', 'cliff'], ['must', 'immediately', 'stop', 'dog', 'attacking', 'child'], ['brother', 'critical', 'condition', 'injury'], ['eat', 'food', 'next', 'day', 'die'], ['son', 'lost', 'need', 'find', 'urgently'], ['need', 'help', 'someone', 'kindapped', 'father'], ['going', 'die', 'escape'], ['going', 'kill', 'keep', 'insisting'], ['dire', 'need', 'help'], ['son', 'stranded', 'need', 'help'], ['many', 'people', 'stranded', 'roof', 'building', 'due', 'tsunami'], ['need', 'sara', 'reply', 'text', 'soon', 'possible'], ['need', 'project', 'completed', 'evening'], ['need', 'pay', 'electricity', 'bill', 'tonight', 'loses', 'electrical', 'service'], ['need', 'pay', 'debt', 'midnight'], ['mom', 'asked', 'clean', 'room', 'today'], ['worker', 'want', 'cup', 'coffee', 'soon'], ['teacher', 'want', 'joe', 'stop', 'sometime', 'noon', 'pick', 'textbook'], ['leave', 'soon', 'business', 'conference', 'california'], ['theater', 'closed', 'immediately', 'reopen', 'till', 'next', 'week'], ['need', 'complete', 'assignment', 'soon', 'possible'], ['going', 'miss', 'flight', 'dont', 'get', 'ready', 'soon'], ['need', 'turn', 'assignment'], ['really', 'need', 'help', 'assignment'], ['get', 'food', 'starving', 'man'], ['would', 'like', 'popcorn', 'movie'], ['scheduled', 'appointment', 'dentist', 'regular', 'checkup'], ['sarah', 'kid', 'would', 'like', 'dog'], ['last', 'priority', 'watching', 'tv'], ['shop', 'owner', 'said', 'would', 'like', 'customer', 'fill', 'optional', 'survey'], ['want', 'come', 'later', 'watch', 'movie'], ['friend'], ['game', 'last', 'night', 'exciting'], ['congratulation', 'getting', 'married'], ['friend', 'seems', 'like', 'nice', 'person'], ['dont', 'anything'], ['going', 'vacation', 'next', 'month'], ['next', 'week', 'uncle', 'come', 'visit'], ['hope', 'fun', 'trip'], ['tomorrow', 'start', 'school']]

# %%
# use fasttext and get pretrained word embeddings 

from gensim.models import KeyedVectors

model = KeyedVectors.load_word2vec_format('../wiki-news-300d-1M.vec')

# %%
trained_embedding_dictionnary = {}

for x in model.index_to_key:
  trained_embedding_dictionnary[x] = model.get_vector(x)

print(len(trained_embedding_dictionnary))
# Out:
# 999994

# %%
# use tokenizer and get an embedding matrix that maps integer values with the word embeddings  
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
import numpy as np

tokenizer = Tokenizer()
tokenizer.fit_on_texts(cleaned_data)

word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))

num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, 300))

for word, i in word_index.items():
    if i > num_words:
        continue
    embedding_vector = trained_embedding_dictionnary.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

print(embedding_matrix)
# Out:
# Found 156 unique tokens.
# [[ 0.          0.          0.         ...  0.          0.
#    0.        ]
#  [-0.0577     -0.0113     -0.0396     ...  0.21349999  0.0483
#    0.0078    ]
#  [-0.20739999 -0.0697      0.031      ...  0.22480001  0.2559
#   -0.021     ]
#  ...
#  [-0.1002      0.1201     -0.0753     ...  0.2572      0.29210001
#   -0.12549999]
#  [-0.1246      0.0086      0.009      ...  0.1815     -0.1338
#    0.0515    ]
#  [-0.0428     -0.0433      0.0541     ...  0.0488     -0.0305
#    0.0659    ]]

# %%
#get training, validation, and testing data 
VALIDATION_SPLIT = 0.2
sequences = tokenizer.texts_to_sequences(cleaned_data)

urgency_pad = pad_sequences(sequences, maxlen=100) # to later try - base length on mean value of sentence lengths 
label = np.array((dataset['critical'].values, dataset['warning'].values, dataset['info'].values)).T
print('Shape of urgency tensor:', urgency_pad.shape)
print('Shape of label tensor:', label.shape)

indices = np.arange(urgency_pad.shape[0])
np.random.shuffle(indices)
urgency_pad = urgency_pad[indices]
label = label[indices]
num_validation_samples = int(VALIDATION_SPLIT * urgency_pad.shape[0])

X_train_pad = urgency_pad[:-num_validation_samples]
y_train = label[:-num_validation_samples]
X_test_pad = urgency_pad[-num_validation_samples:]
y_test = label[-num_validation_samples:]
# Out:
# Shape of urgency tensor: (44, 100)
# Shape of label tensor: (44, 3)

# %%
# create an LSTM model 
import tensorflow as tf
import keras 
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, GRU
from keras.layers import Embedding
from keras.initializers import Constant
import matplotlib.pyplot as plt

model = Sequential()
embedding_layer = Embedding(num_words,
                            300,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=100,
                            trainable=False)
model.add(embedding_layer)
model.add(LSTM(units=32,  dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(3, activation='softmax'))

# try using different optimizers and different optimizer configs
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

print('Summary of the built model...')
print(model.summary())

# fit the model
history = model.fit(X_train_pad, y_train, batch_size=4, epochs=25, validation_data=(X_test_pad, y_test), verbose=2)

num_epochs = len(history.history['loss'])
epochs_range = range(0, num_epochs)
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
# Out:
# Summary of the built model...
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_7 (Embedding)     (None, 100, 300)          47100
#
#  lstm_5 (LSTM)               (None, 64)                93440
#
#  dense_5 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 140,735
# Trainable params: 93,635
# Non-trainable params: 47,100
# _________________________________________________________________
# None
# Epoch 1/25
# 9/9 - 3s - loss: 1.0847 - accuracy: 0.4444 - val_loss: 1.1186 - val_accuracy: 0.1250 - 3s/epoch - 323ms/step
# Epoch 2/25
# 9/9 - 1s - loss: 1.0027 - accuracy: 0.6389 - val_loss: 1.1487 - val_accuracy: 0.0000e+00 - 583ms/epoch - 65ms/step
# Epoch 3/25
# 9/9 - 1s - loss: 0.9362 - accuracy: 0.7222 - val_loss: 1.0689 - val_accuracy: 0.3750 - 617ms/epoch - 69ms/step
# Epoch 4/25
# 9/9 - 1s - loss: 0.8542 - accuracy: 0.8889 - val_loss: 1.0503 - val_accuracy: 0.3750 - 534ms/epoch - 59ms/step
# Epoch 5/25
# 9/9 - 1s - loss: 0.7562 - accuracy: 0.8889 - val_loss: 1.0161 - val_accuracy: 0.3750 - 580ms/epoch - 64ms/step
# Epoch 6/25
# 9/9 - 1s - loss: 0.6445 - accuracy: 0.8889 - val_loss: 0.9212 - val_accuracy: 0.3750 - 532ms/epoch - 59ms/step
# Epoch 7/25
# 9/9 - 1s - loss: 0.5145 - accuracy: 0.8889 - val_loss: 0.8045 - val_accuracy: 0.7500 - 517ms/epoch - 57ms/step
# Epoch 8/25
# 9/9 - 1s - loss: 0.4256 - accuracy: 0.9444 - val_loss: 0.6072 - val_accuracy: 0.8750 - 513ms/epoch - 57ms/step
# Epoch 9/25
# 9/9 - 1s - loss: 0.3004 - accuracy: 0.9444 - val_loss: 0.6815 - val_accuracy: 0.8750 - 558ms/epoch - 62ms/step
# Epoch 10/25
# 9/9 - 1s - loss: 0.2125 - accuracy: 0.9722 - val_loss: 0.7299 - val_accuracy: 0.7500 - 548ms/epoch - 61ms/step
# Epoch 11/25
# 9/9 - 1s - loss: 0.1468 - accuracy: 0.9722 - val_loss: 0.7977 - val_accuracy: 0.7500 - 556ms/epoch - 62ms/step
# Epoch 12/25
# 9/9 - 1s - loss: 0.1026 - accuracy: 1.0000 - val_loss: 0.9860 - val_accuracy: 0.3750 - 522ms/epoch - 58ms/step
# Epoch 13/25
# 9/9 - 1s - loss: 0.0897 - accuracy: 0.9722 - val_loss: 0.9924 - val_accuracy: 0.7500 - 511ms/epoch - 57ms/step
# Epoch 14/25
# 9/9 - 1s - loss: 0.0666 - accuracy: 1.0000 - val_loss: 0.6930 - val_accuracy: 0.7500 - 537ms/epoch - 60ms/step
# Epoch 15/25
# 9/9 - 1s - loss: 0.0592 - accuracy: 1.0000 - val_loss: 0.6243 - val_accuracy: 0.8750 - 517ms/epoch - 57ms/step
# Epoch 16/25
# 9/9 - 1s - loss: 0.0491 - accuracy: 1.0000 - val_loss: 0.8045 - val_accuracy: 0.7500 - 533ms/epoch - 59ms/step
# Epoch 17/25
# 9/9 - 1s - loss: 0.0383 - accuracy: 1.0000 - val_loss: 1.1572 - val_accuracy: 0.7500 - 540ms/epoch - 60ms/step
# Epoch 18/25
# 9/9 - 1s - loss: 0.0270 - accuracy: 1.0000 - val_loss: 1.5038 - val_accuracy: 0.7500 - 544ms/epoch - 60ms/step
# Epoch 19/25
# 9/9 - 1s - loss: 0.0205 - accuracy: 1.0000 - val_loss: 1.6046 - val_accuracy: 0.6250 - 560ms/epoch - 62ms/step
# Epoch 20/25
# 9/9 - 1s - loss: 0.0163 - accuracy: 1.0000 - val_loss: 1.4747 - val_accuracy: 0.7500 - 506ms/epoch - 56ms/step
# Epoch 21/25
# 9/9 - 1s - loss: 0.0136 - accuracy: 1.0000 - val_loss: 1.4313 - val_accuracy: 0.7500 - 516ms/epoch - 57ms/step
# Epoch 22/25
# 9/9 - 1s - loss: 0.0154 - accuracy: 1.0000 - val_loss: 1.6157 - val_accuracy: 0.7500 - 588ms/epoch - 65ms/step
# Epoch 23/25
# 9/9 - 1s - loss: 0.0104 - accuracy: 1.0000 - val_loss: 1.5254 - val_accuracy: 0.7500 - 531ms/epoch - 59ms/step
# Epoch 24/25
# 9/9 - 1s - loss: 0.0081 - accuracy: 1.0000 - val_loss: 1.3288 - val_accuracy: 0.7500 - 572ms/epoch - 64ms/step
# Epoch 25/25
# 9/9 - 1s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.1067 - val_accuracy: 0.7500 - 594ms/epoch - 66ms/step

# %%
plt.figure(figsize=(8, 12))

plt.subplot(2, 1, 1)
plt.plot(epochs_range, train_accuracy, "g", label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, "b", label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.subplot(2, 1, 2)
plt.plot(epochs_range, train_loss, "g", label='Training Loss')
plt.plot(epochs_range, val_loss, "b", label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# evaluate the model and test on some new data 

loss, accuracy = model.evaluate(X_test_pad, y_test, batch_size=128)
print('Accuracy: %f' % (accuracy*100))

def test_model(test):
  # removes punctuation in the sentence
  test = re.sub(r'[^\w\s]', '', test)
  # gets all of the words in the sentence 
  words = word_tokenize(test)
  # converts all the words to lowercase
  words = [w.lower() for w in words]
  # retrieves a set of all of the stopwords in English 
  stop_words = set(stopwords.words('english'))
  # removes the stopwords in the sentence
  words = [w for w in words if not w in stop_words]


  sequences = tokenizer.texts_to_sequences([words])


  review_pad = pad_sequences(sequences, maxlen=100)
    
  encoding = ["critical", "warning", "info"]
  probabilities = model.predict(review_pad)
  prediction = np.argmax(probabilities)

  print('Sentence being analyzed by the model: ', test)
  print(f'Prediction: {encoding[prediction]} with probability {probabilities[0][prediction] * 100}%')


test_samples = ["You have to leave the building immediately", "Six people are in dire need of food", "You need to do your homework right now",
"You can walk your dog later today",
"Your dog urgently needs to go on a walk right now", "He is in need of a surgery", 
"25 people are reported as missing today",
"You can hand in your test when you feel like it", "the building is burning and they need assistance", "a hurricane has destroyed 50 homes", 
"The principal says that you need to come in for a meeting about your child's behavior", "The stagehand would like a break", 
"The worker wants to go on a vacation"] 

for test in test_samples:
  test_model(test)
# Out:
# 1/1 [==============================] - 0s 337ms/step - loss: 1.4056 - accuracy: 0.7500
# Accuracy: 75.000000
# 1/1 [==============================] - 0s 302ms/step
# Sentence being analyzed by the model:  You have to leave the building immediately
# Prediction: warning with probability 81.59673810005188%
# 1/1 [==============================] - 0s 33ms/step
# Sentence being analyzed by the model:  Six people are in dire need of food
# Prediction: critical with probability 87.43203282356262%
# 1/1 [==============================] - 0s 31ms/step
# Sentence being analyzed by the model:  You need to do your homework right now
# Prediction: critical with probability 44.626203179359436%
# 1/1 [==============================] - 0s 31ms/step
# Sentence being analyzed by the model:  You can walk your dog later today
# Prediction: info with probability 55.79623579978943%
# 1/1 [==============================] - 0s 31ms/step
# Sentence being analyzed by the model:  Your dog urgently needs to go on a walk right now
# Prediction: critical with probability 79.10635471343994%
# 1/1 [==============================] - 0s 35ms/step
# Sentence being analyzed by the model:  He is in need of a surgery
# Prediction: critical with probability 44.626203179359436%
# 1/1 [==============================] - 0s 33ms/step
# Sentence being analyzed by the model:  25 people are reported as missing today
# Prediction: critical with probability 54.1517972946167%
# 1/1 [==============================] - 0s 34ms/step
# Sentence being analyzed by the model:  You can hand in your test when you feel like it
# Prediction: info with probability 57.567429542541504%
# 1/1 [==============================] - 0s 32ms/step
# Sentence being analyzed by the model:  the building is burning and they need assistance
# Prediction: warning with probability 55.01766800880432%
# 1/1 [==============================] - 0s 31ms/step
# Sentence being analyzed by the model:  a hurricane has destroyed 50 homes
# Prediction: critical with probability 62.37366795539856%
# 1/1 [==============================] - 0s 31ms/step
# Sentence being analyzed by the model:  The principal says that you need to come in for a meeting about your childs behavior
# Prediction: critical with probability 55.4696261882782%
# 1/1 [==============================] - 0s 31ms/step
# Sentence being analyzed by the model:  The stagehand would like a break
# Prediction: info with probability 59.12843346595764%
# 1/1 [==============================] - 0s 32ms/step
# Sentence being analyzed by the model:  The worker wants to go on a vacation
# Prediction: warning with probability 43.01761984825134%

# %% [markdown]
# # Ecommerce Dataset

# %%
# Load the dataset
ecommerce_dataset = pd.read_csv("../ecommerceDataset.csv", names=["label", "description"])
ecommerce_dataset = ecommerce_dataset[["description", "label"]]

# Clean the data - drop duplicates and missing values
ecommerce_dataset.dropna(inplace=True)
ecommerce_dataset.drop_duplicates(inplace=True)
ecommerce_dataset.reset_index(drop=True, inplace=True)

# One hot encoding
ohe = pd.get_dummies(ecommerce_dataset["label"])
data = pd.concat([ecommerce_dataset["description"], ohe], axis=1)

ecommerce_dataset
# Out:
#                                              description        label
# 0      Paper Plane Design Framed Wall Hanging Motivat...    Household
# 1      SAF 'Floral' Framed Painting (Wood, 30 inch x ...    Household
# 2      SAF 'UV Textured Modern Art Print Framed' Pain...    Household
# 3      SAF Flower Print Framed Painting (Synthetic, 1...    Household
# 4      Incredible Gifts India Wooden Happy Birthday U...    Household
# ...                                                  ...          ...
# 27797  Micromax Bharat 5 Plus Zero impact on visual d...  Electronics
# 27798  Microsoft Lumia 550 8GB 4G Black Microsoft lum...  Electronics
# 27799  Microsoft Lumia 535 (Black, 8GB) Colour:Black ...  Electronics
# 27800  Karbonn Titanium Wind W4 (White) Karbonn Titan...  Electronics
# 27801  Nokia Lumia 530 (Dual SIM, Grey) Colour:Grey  ...  Electronics
#
# [27802 rows x 2 columns]

# %%
# Text normalization
lines = data['description'].values.tolist()
ecommerce_cleaned_data = text_normalization(lines)

# %%
#get training, validation, and testing data 
VALIDATION_SPLIT = 0.2
max_length = 1000
sequences = tokenizer.texts_to_sequences(ecommerce_cleaned_data)

urgency_pad = pad_sequences(sequences, maxlen=max_length) # to later try - base length on mean value of sentence lengths 
label = np.array((data['Books'].values, data['Clothing & Accessories'].values, data['Electronics'].values, data['Household'].values)).T
print('Shape of urgency tensor:', urgency_pad.shape)
print('Shape of label tensor:', label.shape)

indices = np.arange(urgency_pad.shape[0])
np.random.shuffle(indices)
urgency_pad = urgency_pad[indices]
label = label[indices]
num_validation_samples = int(VALIDATION_SPLIT * urgency_pad.shape[0])

X_train_pad = urgency_pad[:-num_validation_samples]
y_train = label[:-num_validation_samples]
X_test_pad = urgency_pad[-num_validation_samples:]
y_test = label[-num_validation_samples:]
# Out:
# Shape of urgency tensor: (27802, 1000)
# Shape of label tensor: (27802, 4)

# %%
# create an LSTM model 
import tensorflow as tf
import keras 
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, GRU
from keras.layers import Embedding
from keras.initializers import Constant
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

model = Sequential()
es = EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True,
)
embedding_layer = Embedding(num_words,
                            300,
                            embeddings_initializer=Constant(embedding_matrix),
                            input_length=max_length,
                            trainable=False)
model.add(embedding_layer)
model.add(LSTM(units=32,  dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(4, activation='softmax'))

# try using different optimizers and different optimizer configs
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

print('Summary of the built model...')
print(model.summary())

# fit the model
history = model.fit(X_train_pad, y_train, batch_size=10, epochs=35, validation_data=(X_test_pad, y_test), callbacks=[es], verbose=2)

num_epochs = len(history.history['loss'])
epochs_range = range(0, num_epochs)
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']
# Out:
# Summary of the built model...
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_11 (Embedding)    (None, 1000, 300)         47100
#
#  lstm_9 (LSTM)               (None, 32)                42624
#
#  dense_9 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 89,856
# Trainable params: 42,756
# Non-trainable params: 47,100
# _________________________________________________________________
# None
# Epoch 1/35

# %%
plt.figure(figsize=(8, 12))

plt.subplot(2, 1, 1)
plt.plot(epochs_range, train_accuracy, "g", label='Training Accuracy')
plt.plot(epochs_range, validation_accuracy, "b", label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.subplot(2, 1, 2)
plt.plot(epochs_range, train_loss, "g", label='Training Loss')
plt.plot(epochs_range, val_loss, "b", label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
# evaluate the model and test on some new data 

# loss, accuracy = model.evaluate(X_test_pad, y_test, batch_size=128)
# print('Accuracy: %f' % (accuracy*100))

def test_model(test):
  # removes punctuation in the sentence
  test = re.sub(r'[^\w\s]', '', test)
  # gets all of the words in the sentence 
  words = word_tokenize(test)
  # converts all the words to lowercase
  words = [w.lower() for w in words]
  # retrieves a set of all of the stopwords in English 
  stop_words = set(stopwords.words('english'))
  # removes the stopwords in the sentence
  words = [w for w in words if not w in stop_words]


  sequences = tokenizer.texts_to_sequences([words])


  review_pad = pad_sequences(sequences, maxlen=max_length)
    
  encoding = ["Books", "Clothing & Accessories", "Electronics", "Household"]
  probabilities = model.predict(review_pad)
  prediction = np.argmax(probabilities)

#   print('Sentence being analyzed by the model: ', test)
#   print(f'Prediction: {encoding[prediction]} with probability {probabilities[0][prediction] * 100}%')
  print(probabilities)

test_household = "Table Lamp with Pull Chain: The USB Bedside Table Lamp comes with a stylish pull chain to control the lamp, you can easy to turn on or turn off the light by pulling the chain, even in the darkness."
test_clothing = "A workwear staple, this men's pocket t-shirt is equal parts durable and comfortable. It has an original fit, Carhartt's roomiest cut. The heavyweight fabric only gets softer with time."
test_books = "NEW YORK TIMES BESTSELLER • The epic tale of a woman who breathes a fantastical empire into existence, only to be consumed by it over the centuries—from the transcendent imagination of Booker Prize–winning, internationally bestselling author Salman Rushdie"
test_electronics = "Dominate on a different scale with the Razer Huntsman Mini TKL — a 60% gaming keyboard with cutting-edge Razer Clicky Optical Switches. Highly portable and ideal for streamlined setups, it’s time to experience lightning-fast actuation in our most compact form factor yet."

test_samples = [test_household, test_clothing, test_books, test_electronics] 

for test in test_samples:
  test_model(test)
# Out:
# 1/1 [==============================] - 0s 75ms/step
# [[0.09354764 0.14891577 0.33997855 0.41755807]]
# 1/1 [==============================] - 0s 68ms/step
# [[0.25770235 0.23051046 0.20641352 0.3053737 ]]
# 1/1 [==============================] - 0s 71ms/step
# [[0.25770235 0.23051046 0.20641352 0.3053737 ]]
# 1/1 [==============================] - 0s 68ms/step
# [[0.02927865 0.06854372 0.3094505  0.5927272 ]]
